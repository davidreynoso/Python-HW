# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sl/fyghq6k55n30j6x1qc8gmlrw0000gn/T/ipykernel_31944/4208845215.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('data.csv')
#       4 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# # Cleanup

# %%
cols = ['Species',
        'Region',
        'Island',
        'Culmen Depth (mm)',
        'Culmen Length (mm)',
        'Flipper Length (mm)',
        'Body Mass (g)',
        'Sex',]

ff= df[cols]
ff=ff.dropna()
ff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sl/fyghq6k55n30j6x1qc8gmlrw0000gn/T/ipykernel_31944/973123430.py in <module>
#       8         'Sex',]
#       9
# ---> 10 ff= df[cols]
#      11 ff=ff.dropna()
#      12 ff
#
# NameError: name 'df' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
#cleanup- REmove all cols we are not going to use
#train test split our test and train models (20-80?)
#remove the Nan's int he columns we are going to use

# %% [markdown]
# # Exploritory Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(df, hue='Species',vars=["Culmen Length (mm)",'Flipper Length (mm)','Culmen Depth (mm)',"Body Mass (g)"], kind='kde')
plt[0].show()

#need to figure out how to not double plot...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/sl/fyghq6k55n30j6x1qc8gmlrw0000gn/T/ipykernel_31944/1436250739.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 sns.pairplot(df, hue='Species',vars=["Culmen Length (mm)",'Flipper Length (mm)','Culmen Depth (mm)',"Body Mass (g)"], kind='kde')
#       4 plt[0].show()
#       5
#
# NameError: name 'df' is not defined

# %%
sns.histplot(ff, x="Body Mass (g)", y="Species", hue="Island", alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so
p = so.Plot(ff, "Species", "Island").facet("Island", wrap=3)
p.add(so.Area(), color="Species")
#https://seaborn.pydata.org/generated/seaborn.objects.Area.html
#fukin website lied to me ;<
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/sl/fyghq6k55n30j6x1qc8gmlrw0000gn/T/ipykernel_31944/4229727580.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 import seaborn.objects as so
#       4 p = so.Plot(ff, "Species", "Island").facet("Island", wrap=3)
#       5 p.add(so.Area(), color="Species")
#
# ModuleNotFoundError: No module named 'seaborn.objects'

# %% [markdown]
# # Feature Selection
